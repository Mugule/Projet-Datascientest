# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd
from datetime import datetime, timedelta
from tqdm import tqdm

# Dates de début et de fin de chaque jour de 2017
start_date = datetime(2016, 1, 1)
end_date = datetime(2023, 1, 3)
date_range = [start_date + timedelta(days=x) for x in range((end_date-start_date).days)]

# Liste de requêtes
queries = []
for i in range(len(date_range)-1):
    query = 'Zelda OR #ZELDA OR BOTW OR #BOTW OR Breath of the Wild OR #breathofthewild since:{} until:{} filter:twimg min_faves:50'
    query = query.format(date_range[i].strftime('%Y-%m-%d'), date_range[i+1].strftime('%Y-%m-%d'))
    queries.append(query)

# Scraper les tweets pour chaque requête et trier par le nombre de likes
tweets = []
for query in tqdm(queries):
    tweet_list = []
    for tweet in sntwitter.TwitterSearchScraper(query).get_items():
        tweet_list.append([tweet.date, tweet.user.username, tweet.user.location, tweet.rawContent, 
                           tweet.replyCount, tweet.likeCount, tweet.retweetCount, tweet.user.followersCount, 
                           tweet.user.friendsCount, tweet.hashtags, tweet.lang, tweet.sourceLabel, 
                           tweet.links, tweet.mentionedUsers])
    tweet_list.sort(key=lambda x: x[3], reverse=True)  # Tri des tweets par le nombre de likes décroissant
    tweets.extend(tweet_list[:50])  # Ajout des 50 premiers tweets de la liste triée

# Créer un DataFrame à partir des tweets récupérés
df = pd.DataFrame(tweets, columns=['Date', 'Username', 'Location', 'Text', 'Reply', 'Like', 
                                   'Retweet', 'User Followers count', 'User Following count', 
                                   'Hashtags', 'Lang', 'sourceLabel', 'Links', 'Mentioned Users'])

# Enregistrer le DataFrame dans un fichier CSV
df.to_csv('top_tweets_2017_to_2022_botw.csv')

# Afficher les 5 premières lignes du DataFrame
df.head(5)
# Out:
# 100%|███████████████████████████████████████| 2558/2558 [48:12<00:00,  1.13s/it]
#                        Date      Username       Location  \
# 0 2016-06-14 16:24:13+00:00      INSIDEjp             東京
# 1 2016-06-14 16:15:45+00:00       famitsu
# 2 2016-06-14 17:29:40+00:00     kotoriiyo        Germany
# 3 2016-06-14 16:28:35+00:00    ZachariusD  San Francisco
# 4 2016-06-14 22:37:13+00:00  howhowhoward    Burbank, CA
#
#                                                 Text  Reply  Like  Retweet  \
# 0  『ゼルダの伝説』最新作のサブタイトルは「BREATH OF THE WILD」 https:...      0   105      121
# 1  『ゼルダの伝説』最新作『THE LEGEND OF ZELDA BREATH OF THE ...      4   539      875
# 2  link in the legend of zelda: breath of the wil...      7   522      487
# 3  don't even know where to begin with Zelda. Thi...     12   748      298
# 4  breath of the wild box art LEAKED https://t.co...      0    68       17
#
#    User Followers count  User Following count Hashtags Lang  \
# 0                 72982                 20315     None   ja
# 1               1030083                 44317     None   ja
# 2                  2835                  1005     None   en
# 3                 24771                  1004     None   en
# 4                  3933                   470     None   en
#
#           sourceLabel                                              Links  \
# 0  Twitter Web Client  [TextLink(text='inside-games.jp/article/2016/0...
# 1             famibot  [TextLink(text='famitsu.com/news/201606/15…', ...
# 2  Twitter Web Client                                               None
# 3  Twitter Web Client                                               None
# 4  Twitter Web Client                                               None
#
#   Mentioned Users
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None
